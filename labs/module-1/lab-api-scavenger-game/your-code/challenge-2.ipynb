# %%
# enter your code below

import json
import requests 

HEADER = {'Authorization': 'token be7afbfe7c606ef805a13172d4c7dd0baa6d8198'}

def github_request(url, headers):
    return requests.get(url, headers=headers)

commits = github_request('http://api.github.com/repos/ironhack-labs/data-labs/commits', HEADER).json()

# %%
print(json.dumps(commits, indent=2))
# Out:
# [
#   {
#     "sha": "a8af4349e1f2525297e57293f8ee2bd38a59294f",
#     "node_id": "MDY6Q29tbWl0MTQ3NjgzNTQwOmE4YWY0MzQ5ZTFmMjUyNTI5N2U1NzI5M2Y4ZWUyYmQzOGE1OTI5NGY=",
#     "commit": {
#       "author": {
#         "name": "kbartonhenry",
#         "email": "k.bartonhenry@gmail.com",
#         "date": "2019-07-03T07:37:34Z"
#       },
#       "committer": {
#         "name": "GitHub",
#         "email": "noreply@github.com",
#         "date": "2019-07-03T07:37:34Z"
#       },
#       "message": "typo fix",
#       "tree": {
#         "sha": "58da0b3f94798ee478a40cb43c1f928343f8cd5c",
#         "url": "https://api.github.com/repos/ironhack-labs/data-labs/git/trees/58da0b3f94798ee478a40cb43c1f928343f8cd5c"
#       },
#       "url": "https://api.github.com/repos/ironhack-labs/data-labs/git/commits/a8af4349e1f2525297e57293f8ee2bd38a59294f",
#       "comment_count": 0,
#       "verification": {
#         "verified": true,
#         "reason": "valid",
# ...

# %%
commits_count = 0
for commit in commits:
    commits_count += 1

commits_count
# Out:
# 30
