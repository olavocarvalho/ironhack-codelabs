# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
import random


# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.
GAME_OPTIONS = ['stone', 'paper', 'scissors']

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
NUMBER_OF_GAMES = 3

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
MUST_WINS = 2

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.

def pick_option(options):
    return random.choice(options)

# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.

def ask_player_option(options):
    while True:
        answered = input("stone, paper or scissors? ").lower()
        if answered not in GAME_OPTIONS:
            continue
        else:
            break
    return answered


# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins

def run_combat(player_option, machine_option, options_range):
    if player_option not in GAME_OPTIONS or machine_option not in options_range:
        return "invalid inputs"
    else:
        if player_option == machine_option:
            return 0
        elif player_option == "stone":
            if machine_option == "paper":
                return 1
            else:
                return 2
        elif player_option == "paper":
            if machine_option == "scissors":
                return 1
            else:
                return 2
        elif player_option == "scissors":
            if machine_option == "stone":
                return 1
            else:
                return 2
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

def update_game(player_option, machine_option, round_winner):
    print("Player choice: ", player_option)
    print("Machine choice: ", machine_option)
    print("Round winner: ", round_winner)
    print("Player: ", player_score)
    print("Machine: ", machine_score)

# Create two variables that accumulate the wins of each participant
player_score = 0
machine_score = 0
number_of_games = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

while (player_score < MUST_WINS and machine_score < MUST_WINS) or (number_of_games < MAX_GAMES):
    machine_option = pick_option(GAME_OPTIONS)
    player_option  = ask_player_option(GAME_OPTIONS)
    round = run_combat(player_option, machine_option, GAME_OPTIONS)
    if round == 1:
        machine_score += 1
        round_winner = "Machine"
        print(machine_score)
    elif round == 2:
        player_score += 1
        round_winner = "Player"
        print(player_score)
    update_game(machine_option, player_option, round_winner)
    
# Print by console the winner of the game based on who has more accumulated wins
if player_score > machine_score:
    print("Player wins!")
elif machine_score > player_score:
    print("Machine wins!")
else:
    print("Error!")
# Out:
# stone, paper or scissors? gygygy
# stone, paper or scissors? ftftf
# stone, paper or scissors? uhu
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     884             try:
# --> 885                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     886             except Exception:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     469         """
# --> 470         parts = [self.recv(flags, copy=copy, track=track)]
#     471         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-2afd3d385ca7> in <module>
#      81 while (player_score < MUST_WINS and machine_score < MUST_WINS) or (number_of_games < MAX_GAMES):
#      82     machine_option = pick_option(GAME_OPTIONS)
# ---> 83     player_option  = ask_player_option(GAME_OPTIONS)
#      84     round = run_combat(player_option, machine_option, GAME_OPTIONS)
#      85     if round == 1:
#
# <ipython-input-24-2afd3d385ca7> in ask_player_option(options)
#      26 def ask_player_option(options):
#      27     while True:
# ---> 28         answered = input("stone, paper or scissors? ").lower()
#      29         if answered not in GAME_OPTIONS:
#      30             continue
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858             self._parent_ident,
#     859             self._parent_header,
# --> 860             password=False,
#     861         )
#     862
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     888             except KeyboardInterrupt:
#     889                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 890                 raise KeyboardInterrupt
#     891             else:
#     892                 break
#
# KeyboardInterrupt:

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module
import random


# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking
def ask_number():
    while True:
        answered = input("choose an odd number: ")
        answered = int(answered)
        if answered%2 == 0:
            continue
        else:
            break
    return int(answered)

# Assign a list of 5 possible options.
GAME_OPTIONS = ['stone', 'paper', 'scissors', 'lizard', 'spock']


# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used
MAX_GAMES = ask_number()

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
MUST_WINS = int(MAX_GAMES/2)+1

# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.
def pick_option(options):
    return random.choice(options)

# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.
def ask_player_option(options):
    while True:
        answered = input("stone, paper, scissors, lizard or spock? ").lower()
        if answered not in GAME_OPTIONS:
            continue
        else:
            break
    return answered

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options
def run_combat(player_option, machine_option, options_range):
    if player_option not in GAME_OPTIONS or machine_option not in options_range:
        return "invalid inputs"
    else:
        if player_option == machine_option:
            return 0
        elif player_option == "scissors":
            if machine_option == "stone" or machine_option == "spock":
                return 1
            else:
                return 2
        elif player_option == "paper":
            if machine_option == "scissors" or machine_option == "lizard":
                return 1
            else:
                return 2
        elif player_option == "stone":
            if machine_option == "paper" or machine_option == "spock":
                return 1
            else:
                return 2
        elif player_option == "spock":
            if machine_option == "paper" or machine_option == "lizard":
                return 1
            else:
                return 2
        elif player_option == "lizard":
            if machine_option == "rock" or machine_option == "scissors":
                return 1
            else:
                return 2
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

def update_game(player_option, machine_option, round_winner):
    print("Player choice: ", player_option)
    print("Machine choice: ", machine_option)
    print("Round winner: ", round_winner)
    print("Player: ", player_score)
    print("Machine: ", machine_score)
    
    
# Create two variables that accumulate the wins of each participant

player_score = 0
machine_score = 0
number_of_games = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

while (player_score < MUST_WINS and machine_score < MUST_WINS) or (number_of_games < MAX_GAMES):
    machine_option = pick_option(GAME_OPTIONS)
    player_option  = ask_player_option(GAME_OPTIONS)
    round = run_combat(player_option, machine_option, GAME_OPTIONS)
    if round == 1:
        machine_score += 1
        round_winner = "Machine"
    elif round == 2:
        player_score += 1
        round_winner = "Player"
    number_of_games += 1
    update_game(player_option, machine_option, round_winner)
    
    
# Print by console the winner of the game based on who has more accumulated wins

if player_score > machine_score:
    print("Player wins!")
elif machine_score > player_score:
    print("Machine wins!")
# Out:
# choose an odd number: 5
# stone, paper, scissors, lizard or spock? stone
# Player choice:  stone
# Machine choice:  stone
# Round winner:  Player
# Player:  0
# Machine:  0
# stone, paper, scissors, lizard or spock? stone
# Player choice:  stone
# Machine choice:  scissors
# Round winner:  Player
# Player:  1
# Machine:  0
# stone, paper, scissors, lizard or spock? stone
# Player choice:  stone
# Machine choice:  lizard
# Round winner:  Player
# Player:  2
# Machine:  0
# stone, paper, scissors, lizard or spock? stone
# Player choice:  stone
# Machine choice:  paper
# Round winner:  Machine
# Player:  2
# Machine:  1
# stone, paper, scissors, lizard or spock? scissors
# Player choice:  scissors
# Machine choice:  stone
# Round winner:  Machine
# Player:  2
# Machine:  2
# stone, paper, scissors, lizard or spock? stone
# Player choice:  stone
# Machine choice:  spock
# Round winner:  Machine
# Player:  2
# Machine:  3
# Machine wins!
